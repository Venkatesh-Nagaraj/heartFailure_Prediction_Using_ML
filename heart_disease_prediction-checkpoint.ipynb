# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import seaborn as sb
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('heart_2020_cleaned.csv')

# %%
dataset
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
dataset.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0               3
# 1             0  20.34        0                0       1               0
# 2             0  26.58        1                0       0              20
# 3             0  24.21        0                0       0               0
# 4             0  23.71        0                0       0              28
#
#    MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 0          30.0            0    0            7     5         2
# 1           0.0            0    0           12     5         0
# 2          30.0            0    1            9     5         2
# 3           0.0            0    0           11     5         0
# 4           0.0            1    0            4     5         0
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer
# ...

# %%
dataset['AgeCategory'].value_counts()
# Out:
# 65-69          34151
# 60-64          33686
# 70-74          31065
# 55-59          29757
# 50-54          25382
# 80 or older    24153
# 45-49          21791
# 75-79          21482
# 18-24          21064
# 40-44          21006
# 35-39          20550
# 30-34          18753
# 25-29          16955
# Name: AgeCategory, dtype: int64

# %%
dataset['PhysicalHealth'].value_counts()
# Out:
# 0     226589
# 30     19509
# 2      14880
# 1      10489
# 3       8617
# 5       7606
# 10      5453
# 15      5012
# 7       4629
# 4       4468
# 20      3216
# 14      2893
# 6       1270
# 25      1164
# 8        924
# 21       626
# 12       605
# 28       446
# 29       204
# 9        180
# 18       167
# 16       135
# 27       124
# 17       110
# 13        91
# 22        89
# 11        85
# 24        67
# 26        66
# 23        46
# 19        35
# Name: PhysicalHealth, dtype: int64

# %%
dataset.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
dataset.nunique()
# Out:
# HeartDisease           2
# BMI                 3604
# Smoking                2
# AlcoholDrinking        2
# Stroke                 2
# PhysicalHealth        31
# MentalHealth          31
# DiffWalking            2
# Sex                    2
# AgeCategory           13
# Race                   6
# Diabetic               4
# PhysicalActivity       2
# GenHealth              5
# SleepTime             24
# Asthma                 2
# KidneyDisease          2
# SkinCancer             2
# dtype: int64

# %%
dataset.iloc[:,[0,2,3,4,7,12,15,16,17]]
# Out:
#        HeartDisease Smoking AlcoholDrinking Stroke DiffWalking  \
# 0                No     Yes              No     No          No
# 1                No      No              No    Yes          No
# 2                No     Yes              No     No          No
# 3                No      No              No     No          No
# 4                No      No              No     No         Yes
# ...             ...     ...             ...    ...         ...
# 319790          Yes     Yes              No     No         Yes
# 319791           No     Yes              No     No          No
# 319792           No      No              No     No          No
# 319793           No      No              No     No          No
# 319794           No      No              No     No          No
#
#        PhysicalActivity Asthma KidneyDisease SkinCancer
# 0                   Yes    Yes            No        Yes
# 1                   Yes     No            No         No
# ...

# %%
cat_dict={'Yes':1,'No':0}

# %%
ran=[0,2,3,4,7,12,15,16,17]

# %%
for i in ran:
    dataset.iloc[:,i]=dataset.iloc[:,i].apply(lambda x:cat_dict[x])

# %%
dataset['Diabetic'].value_counts()
# Out:
# No                         269653
# Yes                         40802
# No, borderline diabetes      6781
# Yes (during pregnancy)       2559
# Name: Diabetic, dtype: int64

# %%
plt.figure(figsize=(13,10))
sb.countplot(x=dataset['PhysicalHealth'],data=dataset)
plt.show()

# %%
data_diabet=LabelEncoder()
data_sex=LabelEncoder()
data_age=LabelEncoder()
data_race=LabelEncoder()
data_gen=LabelEncoder()
data_phyh=LabelEncoder()

# %%
dataset['Diabetic']=data_diabet.fit_transform(dataset['Diabetic'])
dataset['Sex']=data_sex.fit_transform(dataset['Sex'])
dataset['AgeCategory']=data_age.fit_transform(dataset['AgeCategory'])
dataset['Race']=data_race.fit_transform(dataset['Race'])
dataset['GenHealth']=data_gen.fit_transform(dataset['GenHealth'])
dataset['PhysicalHealth']=data_phyh.fit_transform(dataset['PhysicalHealth'])

# %%
dataset
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0                  0  16.60        1                0       0               3
# 1                  0  20.34        0                0       1               0
# 2                  0  26.58        1                0       0              20
# 3                  0  24.21        0                0       0               0
# 4                  0  23.71        0                0       0              28
# ...              ...    ...      ...              ...     ...             ...
# 319790             1  27.41        1                0       0               7
# 319791             0  29.84        1                0       0               0
# 319792             0  24.24        0                0       0               0
# 319793             0  32.81        0                0       0               0
# 319794             0  46.56        0                0       0               0
#
# ...

# %% [markdown]
# # Feature Selection using corelation

# %%
cor=dataset.corr()

# %%
sb.pairplot(cor)

# %%
plt.figure(figsize=(13,10))
dataplot = sb.heatmap(dataset.corr(), annot=True)
plt.show()

# %%
dataset['SkinCancer'].value_counts()
# Out:
# 0    289976
# 1     29819
# Name: SkinCancer, dtype: int64

# %%
X_lab=dataset.loc[:,['Smoking','Stroke','DiffWalking','AgeCategory','Diabetic','PhysicalHealth','KidneyDisease']]

# %%
target=dataset['HeartDisease']

# %%
target
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 319790    1
# 319791    0
# 319792    0
# 319793    0
# 319794    0
# Name: HeartDisease, Length: 319795, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_lab, target ,random_state=25,train_size = .80)

# %%
X_train.shape
# Out:
# (255836, 7)

# %% [markdown]
# ## Train the Model

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=25)
model.fit(X_train, y_train)
model.score(X_test,y_test)
# Out:
# 0.9115839834894229

# %%
from sklearn import tree
dt_model = tree.DecisionTreeClassifier(criterion="entropy")

# %%
dt_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
dt_model.score(X_test,y_test)
# Out:
# 0.9117090636188808

# %%
from sklearn.linear_model import LogisticRegression
log_model=LogisticRegression()

# %%
log_model.fit(X_test,y_test)
# Out:
# LogisticRegression()

# %%
log_model.score(X_test,y_test)
# Out:
# 0.9133038352694695

# %% [markdown]
# ### Predict the model

# %%
y_predicted = model.predict(X_test)

# %%
y_predicted
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
X_lab
# Out:
#         Smoking  Stroke  DiffWalking  AgeCategory  Diabetic  PhysicalHealth  \
# 0             1       0            0            7         2               3
# 1             0       1            0           12         0               0
# 2             1       0            0            9         2              20
# 3             0       0            0           11         0               0
# 4             0       0            1            4         0              28
# ...         ...     ...          ...          ...       ...             ...
# 319790        1       0            1            8         2               7
# 319791        1       0            0            3         0               0
# 319792        0       0            0            5         0               0
# 319793        0       0            0            1         0               0
# 319794        0       0            0           12         0               0
#
#         KidneyDisease
# 0                   0
# ...

# %%
true_count=0
false_count=0
for t in y_test:
    t
for p in y_predicted:
    if p==t:
        print(True)
        true_count+=1
    else:
        print(False)
        false_count+=1
print(true_count,false_count)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %%
X_lab
# Out:
#         Smoking  Stroke  DiffWalking  AgeCategory  Diabetic  PhysicalHealth  \
# 0             1       0            0            7         2               3
# 1             0       1            0           12         0               0
# 2             1       0            0            9         2              20
# 3             0       0            0           11         0               0
# 4             0       0            1            4         0              28
# ...         ...     ...          ...          ...       ...             ...
# 319790        1       0            1            8         2               7
# 319791        1       0            0            3         0               0
# 319792        0       0            0            5         0               0
# 319793        0       0            0            1         0               0
# 319794        0       0            0           12         0               0
#
#         KidneyDisease
# 0                   0
# ...

# %%
x_pred=pd.DataFrame({},index=[1])

# %%
x_pred['Smoking']=int(input("Smoking or Not(0/1):"))

x_pred['Stroke']=int(input("Any Stroke Affect(0/1):"))

x_pred['DiffWalking']=int(input("DifferentWalking(0/1)"))

x_pred['AgeCategory']=int(input("Age category:\n 1.18-24 \n 2.25-29 \n 3.30-34 \n 4.35-39 \n 5.40-44 \n 6.45-49 \n 7.50-54 \n 8.55-59 \n 9.60-64 \n 10.65-69 \n 11.70-74 \n 12.75-79 \n 13.18-older: "))

x_pred['Diabetic']=int(input("Diabetic person \n 1.Yes \n 2.No \n 3.No, borderline diabetes \n 4.Yes (during pregnancy) \n...Press 1 to 4: "))

x_pred['PhysicalHealth']=int(input("Physical Health(1-30): "))

x_pred['KidneyDisease']=int(input("KidneyDisease(0/1):"))
if model.predict(x_pred)==1:
    print("YEAH, IS THIS HEART DISEASE..!")
else:
    print("NO..IS NOT HEART DISEASE")
# Out:
# Smoking or Not(0/1):0
# Any Stroke Affect(0/1):1
# DifferentWalking(0/1)1
# Age category:
#  1.18-24
#  2.25-29
#  3.30-34
#  4.35-39
#  5.40-44
#  6.45-49
#  7.50-54
#  8.55-59
#  9.60-64
#  10.65-69
#  11.70-74
#  12.75-79
#  13.18-older: 6
# Diabetic person
#  1.Yes
#  2.No
#  3.No, borderline diabetes
#  4.Yes (during pregnancy)
# ...Press 1 to 4: 1
# Physical Health(1-30): 20
# KidneyDisease(0/1):1
# YEAH, IS THIS HEART DISEASE..!
